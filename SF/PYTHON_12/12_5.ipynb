# %%
import pandas as pd
ratings_1 = pd.read_csv('data/ratings1.csv', sep=',')
ratings_2 = pd.read_csv('data/ratings2.csv', sep=',')
movies = pd.read_csv('data/movies.csv', sep=',')
dates = pd.read_csv('data/dates.csv', sep=',')
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
import datetime as dt

movies['movieId'].nunique()
ratings_1['userId'].nunique()
dates['year']= pd.to_datetime(dates['date'])
print(dates['year'].dt.year.value_counts())
# Out:
# 2000    10061
# 2017     8198
# 2007     7114
# 2016     6703
# 2015     6616
# 2018     6418
# 1996     6040
# 2005     5813
# 2012     4656
# 2008     4351
# 2009     4158
# 2006     4059
# 2003     4014
# 2001     3922
# 2002     3478
# 2004     3279
# 1999     2439
# 2010     2301
# 1997     1916
# 2011     1690
# 2013     1664
# 2014     1439
# 1998      507
# Name: year, dtype: int64

# %%
ratings = pd.concat(objs=[ratings_1, ratings_2], ignore_index=True)
ratings = ratings.drop_duplicates(ignore_index=True)
ratings
# Out:
#         userId  movieId  rating
# 0            1        1     4.0
# 1            1        3     4.0
# 2            1        6     4.0
# 3            1       47     5.0
# 4            1       50     5.0
# ...        ...      ...     ...
# 100831     610   166534     4.0
# 100832     610   168248     5.0
# 100833     610   168250     5.0
# 100834     610   168252     5.0
# 100835     610   170875     3.0
#
# [100836 rows x 3 columns]
