# %%
import requests # Импортируем модуль requests
token = '1154046111540461115404613c1244e54611154115404617261e5656eb61a70fc3feb9e' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/users.get' # Указываем адрес страницы к которой делаем запрос
params = {'user_id': 1, 'v': 5.95, 'fields': 'sex,bdate', 'access_token': token, 'lang': 'ru'} # Перечисляем параметры нашего запроса в словаре params
response = requests.get(url, params=params) # Отправляем запрос
print(response.text) # Выводим текст ответа на экран
# Out:
# {"response":[{"id":1,"bdate":"10.10.1984","sex":2,"first_name":"Павел","last_name":"Дуров","can_access_closed":true,"is_closed":false}]}

# %%
from pprint import pprint # Импортируем функцию pprint()
ids = ",".join(map(str, range(1, 501))) # Формируем строку, содержащую информацию о поле id первых трёх пользователей
params = {'user_ids': ids, 'v': 5.95, 'fields': 'sex,bday', 'access_token': token, 'lang': 'ru'} # Формируем строку параметров
response = requests.get(url, params=params).json() # Посылаем запрос, полученный ответ в формате JSON-строки преобразуем в словарь и выводим на экран его содержимое, используя функцию pprint()
#pprint(response)
female = 0
count = 0
for i in range(0, 500):
    user = response['response'][i]
    if user['sex'] == 1: 
        female += 1
        count += 1
    else:
        if user['sex'] == 2:
            count += 1

display(female/count)
# Out:
# 0.4846335697399527

# %%
import time # Импортируем модуль time

url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес страницы, к которой делаем запрос
count = 1000 
offset = 0  
user_ids = []  
while offset < 5000: 
    params = {'group_id': 'vk', 'v': 5.95, 'count': count, 'offset': offset, 'access_token': token} 
    response = requests.get(url, params = params) 
    data = response.json() 
    user_ids += data['response']['items'] 
    offset += count 
    print('Ожидаю 0.5 секунды...') 
    time.sleep(0.5) 
print('Цикл завершен, offset =',offset)
# Out:
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Цикл завершен, offset = 5000

# %%
import requests # Импортируем модуль requests
from pprint import pprint # Импортируем функцию pprint()

url = 'https://api.vk.com/method/wall.get' # Указываем адрес страницы, к которой делаем запрос
params = {'domain': 'vk', 'filter': 'owner', 'count': 1000, 'offset': 0, 'access_token': token, 'v': 5.95} 
response = requests.get(url, params = params) 
pprint(response.json())
# Out:
# {'response': {'count': 521,
#               'items': [{'attachments': [{'photo': {'access_key': '53c56e2996d8c7b150',
#                                                     'album_id': -7,
#                                                     'date': 1664904724,
#                                                     'id': 457333862,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1326116,
#                                                     'sizes': [{'height': 42,
#                                                                'type': 's',
#                                                                'url': 'https://sun4-11.userapi.com/impg/_NSEG-3ZsDs9i-UdMUH8Ns3wv0zSlxmkwWwzkw/h5QYQRbbRK8.jpg?size=75x42&quality=95&sign=5d6451855da6d7e82048d91bfa3fca00&c_uniq_tag=Lfv2krt5QbdQrpyLquJcw3BEhg1rTUf-UwvoBMCzreI&type=album',
#                                                                'width': 75},
#                                                               {'height': 73,
#                                                                'type': 'm',
#                                                                'url': 'https://sun4-11.userapi.com/impg/_NSEG-3ZsDs9i-UdMUH8Ns3wv0zSlxmkwWwzkw/h5QYQRbbRK8.jpg?size=510x340&quality=95&crop=100,0,1080,720&sign=e33c76aae96bbfb4333acfb0bc76520e&c_uniq_tag=Z5IsNVOTtPF7GduThM1_bTWf7dgXohm1-kNBS1ZIOoM&type=album',
#                                                                'width': 510}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 130,
#                                       'groups_can_post': True},
#                          'date': 1664904760,
#                          'edited': 1664905407,
#                          'from_id': -22822305,
#                          'hash': 'amZco_X9PUaBX-Nb6Q',
#                          'id': 1326116,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 323,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 62, 'user_reposted': 0},
#                          'text': 'Все интересные обновления ВКонтакте за '
#                                  'сентябрь — в одном дайджесте: '
#                                  'vk.cc/ch7TiZ. \n'
#                                  '\n'
#                                  '🍁 '
#                                  '[https://vk.com/blog/daydzhest-obnovleniy-sentyabr?anchor=vk-muzyka|В '
#                                  'VK Музыке] появился раздел «100 личных '
#                                  'плейлистов». В нём можно узнать, что слушают '
#                                  'звёзды и насколько совпадают ваши '
#                                  'музыкальные вкусы.\n'
#                                  '\n'
#                                  '🍁 '
#                                  '[https://vk.com/blog/daydzhest-obnovleniy-sentyabr?anchor=vk-klipy|Клипы] '
#                                  'теперь можно публиковать с компьютера, а в '
#                                  'VK Знакомствах встретить селебрити — '
#                                  'например, Эльдара Джарахова.\n'
#                                  '\n'
#                                  '🍁 '
#                                  '[https://vk.com/blog/daydzhest-obnovleniy-sentyabr?anchor=servisy|В '
#                                  'новом сервисе «Бег»] удобно отслеживать '
#                                  'статистику своих пробежек, соревноваться в '
#                                  'рейтинге и участвовать в спортивных '
#                                  'челленджах.\n'
#                                  '\n'
#                                  '🍁 Проводить онлайн-встречи из '
#                                  'конференц-залов и переговорных поможет '
#                                  '[https://vk.com/blog/daydzhest-obnovleniy-sentyabr?anchor=vk-zvonki|специальное '
#                                  'приложение от VK Звонков].\n'
#                                  '\n'
#                                  '🍁 Разработчики теперь могут бесплатно '
#                                  'использовать в своих проектах '
#                                  '[https://vk.com/blog/daydzhest-obnovleniy-sentyabr?anchor=tekhnologii|нейросетевую '
#                                  'технологию ВКонтакте], которая распознаёт '
#                                  'речь и переводит её в текст. Например, для '
#                                  'голосового управления в играх, расшифровки '
#                                  'интервью и любых других целей.',
#                          'views': {'count': 113278}},
#                         {'attachments': [{'link': {'caption': 'm.vk.com',
#                                                    'description': 'Article',
#                                                    'photo': {'album_id': -66,
#                                                              'date': 1664375424,
#                                                              'id': 457333736,
#                                                              'owner_id': -22822305,
#                                                              'sizes': [{'height': 73,
#                                                                         'type': 'm',
#                                                                         'url': 'https://sun4-12.userapi.com/impg/Qr95Buiv899xTXaLD5tcsQS6x8X-yKmbI_lvMQ/XQTZvaFosDU.jpg?size=130x73&quality=96&sign=8b8bc3193029c28546167900700b1f02&c_uniq_tag=YK7YVousmgcCrgUjbkXXI8tRFadj_ePmsWiRWIgQdcU&type=album',
#                                                                         'width': 807},
#                                                                        {'height': 720,
#                                                                         'type': 'z',
#                                                                         'url': 'https://sun4-12.userapi.com/impg/Qr95Buiv899xTXaLD5tcsQS6x8X-yKmbI_lvMQ/XQTZvaFosDU.jpg?size=1280x720&quality=96&sign=9cfbd380f66afc46e820c0da0099b6c4&c_uniq_tag=z2B-X8-oL_dTlHjFO3yr_OBmpmu3cfRU-UJxFtVv9t0&type=album',
#                                                                         'width': 1280}],
#                                                              'text': '',
#                                                              'user_id': 100},
#                                                    'title': 'Подробнее о '
#                                                             'работе приложений '
#                                                             'VK на устройствах '
#                                                             'Apple',
#                                                    'url': 'https://m.vk.com/@vk-app-ios'},
#                                           'type': 'link'}],
#                          'comments': {'can_post': 1,
#                                       'count': 2168,
#                                       'groups_can_post': True},
#                          'date': 1664267982,
#                          'edited': 1664375558,
#                          'from_id': -22822305,
#                          'hash': 'FcXxoAQW6kSok3GB0A',
#                          'id': 1322999,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 4386,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 5000, 'user_reposted': 0},
#                          'text': 'Друзья!\n'
#                                  '\n'
#                                  'Сейчас некоторые приложения VK заблокированы '
#                                  'Apple, поэтому они недоступны для скачивания '
#                                  'и обновления в App Store.\n'
#                                  '\n'
#                                  'Самое важное: приложения VK, которые уже '
#                                  'были установлены на смартфонах, продолжают '
#                                  'работать. Их основная функциональность будет '
#                                  'привычной и стабильной. Могут возникнуть '
#                                  'затруднения с работой уведомлений и '
#                                  'платежей. Специалисты VK работают над этим. '
#                                  'В последние месяцы реализованы ключевые '
#                                  'обновления на наших основных продуктах, '
#                                  'которые позволят приложениям оставаться '
#                                  'актуальными продолжительное время.\n'
#                                  '\n'
#                                  'Приложение ВКонтакте тоже продолжит работать '
#                                  'на устройствах Apple. Кроме того, вы можете '
#                                  'пользоваться мобильной версией сайта '
#                                  'm.vk.com и десктопной версией с полной '
#                                  'функциональностью.\n'
#                                  '\n'
#                                  'VK продолжит развивать и поддерживать '
#                                  'приложения для iOS. Наши специалисты делают '
#                                  'всё, чтобы сохранить и продолжить улучшать '
#                                  'пользовательский комфорт.\n'
#                                  '\n'
#                                  'Ответили на частые вопросы в статье: '
#                                  'vk.com/@vk-app-ios',
#                          'views': {'count': 1231390}},
#                         {'attachments': [{'type': 'video',
#                                           'video': {'access_key': '5b80a99aca784dc657',
#                                                     'can_add': 1,
#                                                     'can_add_to_faves': 0,
#                                                     'can_comment': 0,
#                                                     'can_like': 1,
#                                                     'can_repost': 1,
#                                                     'can_subscribe': 1,
#                                                     'comments': 0,
#                                                     'date': 1663229343,
#                                                     'description': '',
#                                                     'duration': 20,
#                                                     'first_frame_1280': 'https://i.mycdn.me/getVideoPreview?id=3021861096114&idx=0&type=39&tkn=Mus8U3-2j2FSF_Oai9AB0O7oeZE',
#                                                     'first_frame_130': 'https://i.mycdn.me/getVideoPreview?id=3021861096114&idx=0&type=39&tkn=Mus8U3-2j2FSF_Oai9AB0O7oeZE&fn=vid_sm',
#                                                     'first_frame_160': 'https://i.mycdn.me/getVideoPreview?id=3021861096114&idx=0&type=39&tkn=Mus8U3-2j2FSF_Oai9AB0O7oeZE&fn=vid_d',
#                                                     'first_frame_320': 'https://i.mycdn.me/getVideoPreview?id=3021861096114&idx=0&type=39&tkn=Mus8U3-2j2FSF_Oai9AB0O7oeZE&fn=vid_md',
#                                                     'first_frame_800': 'https://i.mycdn.me/getVideoPreview?id=3021861096114&idx=0&type=39&tkn=Mus8U3-2j2FSF_Oai9AB0O7oeZE&fn=vid_f',
#                                                     'height': 1080,
#                                                     'id': 456241864,
#                                                     'owner_id': -22822305,
#                                                     'photo_1280': 'https://i.mycdn.me/getVideoPreview?id=3021861096114&idx=15&type=39&tkn=G6piAuMCQtnQ22qCLWckMBZnu8s&fn=vid_w',
#                                                     'photo_130': 'https://i.mycdn.me/getVideoPreview?id=3021861096114&idx=15&type=39&tkn=G6piAuMCQtnQ22qCLWckMBZnu8s&fn=vid_s',
#                                                     'photo_320': 'https://i.mycdn.me/getVideoPreview?id=3021861096114&idx=15&type=39&tkn=G6piAuMCQtnQ22qCLWckMBZnu8s&fn=vid_l',
#                                                     'photo_800': 'https://i.mycdn.me/getVideoPreview?id=3021861096114&idx=15&type=39&tkn=G6piAuMCQtnQ22qCLWckMBZnu8s&fn=vid_x',
#                                                     'title': 'VK Звонки',
#                                                     'track_code': 'video_082a0f49qSiPAxjPmiuV0U8ljFSi8NUtZ62LyPBJYoE1x3-N2wSYCZEBH6iZKpTRTUyJYZTC4Rxfm7_MhygO7TXWUr_p',
#                                                     'views': 573843,
#                                                     'width': 1920}}],
#                          'comments': {'can_post': 1,
#                                       'count': 1195,
#                                       'groups_can_post': True},
#                          'date': 1663240511,
#                          'from_id': -22822305,
#                          'hash': 'z3ejBjdRmLq3X371QQ',
#                          'id': 1320761,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 1637,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 725, 'user_reposted': 0},
#                          'text': 'Почему VK Звонки?\n'
#                                  'Потому что даже в домашнем офисе важно '
#                                  'сосредоточиться. Потому что работа со всей '
#                                  'командой на расстоянии — это большой и '
#                                  'продуктивный процесс. Потому что на занятиях '
#                                  'с учениками хочется разбираться в задачах, а '
#                                  'не в настройках. Мы понимаем это и создаём '
#                                  'для вас VK Звонки. \n'
#                                  ' \n'
#                                  '• VK Звонки бесплатны для всех, в любых '
#                                  'условиях использования. \n'
#                                  '• Можно звонить в десктопном и мобильном '
#                                  'приложении, а также прямо ВКонтакте. \n'
#                                  '• Нет лимитов по времени и количеству '
#                                  'участников. \n'
#                                  '• Шеринг экрана 4к, шумоподавление и все '
#                                  'привычные функции видеоконференций доступны '
#                                  'в полном объёме и без дополнительной '
#                                  'платы. \n'
#                                  '• Удобно планировать встречи и подключаться '
#                                  'к звонкам анонимно.\n'
#                                  '\n'
#                                  'Созвонимся?',
#                          'views': {'count': 643728}},
#                         {'attachments': [{'link': {'caption': 'vc.ru',
#                                                    'description': 'Привет! '
#                                                                   'Меня зовут '
#                                                                   'Иван '
#                                                                   'Расторгуев, '
#                                                                   'я руковожу '
#                                                                   'направлением '
#                                                                   'развития '
#                                                                   'контента и '
#                                                                   'монетизации '
#                                                                   'VK Mini '
#                                                                   'Apps. Это '
#                                                                   'платформа '
#                                                                   'мини-приложений '
#                                                                   'внутри '
#                                                                   'ВКонтакте, '
#                                                                   'которые '
#                                                                   'решают '
#                                                                   'разные '
#                                                                   'задачи: '
#                                                                   'помогают '
#                                                                   'следить за '
#                                                                   'здоровьем, '
#                                                                   'знакомиться, '
#                                                                   'совершать '
#                                                                   'покупки, '
#                                                                   'играть или '
#                                                                   'даже искать '
#                                                                   'шаверму '
#                                                                   'поблизости. '
#                                                                   'С момента '
#                                                                   'открытия на '
#                                                                   'платформе '
#                                                                   'появилось '
#                                                                   'уже 53 '
#                                                                   'тысячи…',
#                                                    'photo': {'album_id': -28,
#                                                              'date': 1663066185,
#                                                              'id': 457404960,
#                                                              'owner_id': 2000013296,
#                                                              'sizes': [{'height': 89,
#                                                                         'type': 'a',
#                                                                         'url': 'https://sun4-15.userapi.com/PHapvf-lqpHr5BEhokidXKF-ZezdGrCcSms_XA/8FAQGEVaxyI.jpg',
#                                                                         'width': 200},
#                                                                        {'height': 178,
#                                                                         'type': 'b',
#                                                                         'url': 'https://sun4-11.userapi.com/Em4hOFQR42mzUzWRaNIGoL_pfBBPvTk6ZXVeBw/a4k6bmJCFU4.jpg',
#                                                                         'width': 400},
#                                                                        {'height': 200,
#                                                                         'type': 'c',
#                                                                         'url': 'https://sun4-17.userapi.com/qXfkWvYS6HC_rQSCybux_gmgPX3g6YTcQnXphg/-70utDpir_w.jpg',
#                                                                         'width': 200},
#                                                                        {'height': 100,
#                                                                         'type': 'd',
#                                                                         'url': 'https://sun4-12.userapi.com/mGdnaV7rrQmSuuzEt94CU0Xti7ZL0U1EgL-Awg/bsjIU6GTYUs.jpg',
#                                                                         'width': 100},
#                                                                        {'height': 50,
#                                                                         'type': 'e',
#                                                                         'url': 'https://sun4-11.userapi.com/DD500r29zBoSwPhvgfEDp8z1mF8k4sg8RSNnbg/PmfS8YL8rsY.jpg',
#                                                                         'width': 50},
#                                                                        {'height': 478,
#                                                                         'type': 'k',
#                                                                         'url': 'https://sun4-17.userapi.com/impg/nMgeqEMuuNKneLf8xfxS8KK1rpv6-Wz44HoPyg/LCt4JuwJq_k.jpg?size=1074x478&quality=96&sign=248d7a3ed12d37673c02be5414ea6c04&c_uniq_tag=cZ-R-NPviZ848fYkEm49MhbEsQjoNqIND4RSazQet-c&type=share',
#                                                                         'width': 1074},
#                                                                        {'height': 239,
#                                                                         'type': 'l',
#                                                                         'url': 'https://sun4-17.userapi.com/impg/nMgeqEMuuNKneLf8xfxS8KK1rpv6-Wz44HoPyg/LCt4JuwJq_k.jpg?size=537x239&quality=96&sign=9ba7c2d45f34359d58d15961b9e32d10&c_uniq_tag=B28hRax9Wjhm4oDLHtW5UudFANWgNuOuvZl9fBSYEkw&type=share',
#                                                                         'width': 537},
#                                                                        {'height': 935,
#                                                                         'type': 'o',
#                                                                         'url': 'https://sun4-12.userapi.com/4VXEksHUSq9goSK35soKfrOK3090-ZsYN77Mfw/h_m1720Squs.jpg',
#                                                                         'width': 2099}],
#                                                              'text': '',
#                                                              'user_id': 100},
#                                                    'title': 'Платформа '
#                                                             'мини-приложений: '
#                                                             'зачем создавать '
#                                                             'свой сервис и как '
#                                                             'его '
#                                                             'монетизировать',
#                                                    'url': 'https://vc.ru/vk/496557-platforma-mini-prilozheniy-vk-mini-apps-zachem-sozdavat-svoy-servis-i-kak-ego-monetizirovat'},
#                                           'type': 'link'}],
#                          'comments': {'can_post': 1,
#                                       'count': 255,
#                                       'groups_can_post': True},
#                          'date': 1663082160,
#                          'from_id': -22822305,
#                          'hash': 'LUFcNvILr5FdBoZpEQ',
#                          'id': 1320398,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 1412,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 863, 'user_reposted': 0},
#                          'text': 'Выучить английский, выбрать подарок другу '
#                                  'или найти шаверму поблизости? Всё это можно '
#                                  'сделать в сервисах ВКонтакте. А ещё можно '
#                                  'заработать: сервисы приносят своим авторам '
#                                  'до миллиона рублей в месяц. \n'
#                                  '\n'
#                                  'Если хотите так же, присоединяйтесь к '
#                                  'платформе VK Mini Apps. На ней уже 53 тысячи '
#                                  'полезных сервисов, и это не предел. \n'
#                                  '\n'
#                                  'Как устроена платформа, насколько просто '
#                                  'создать сервис и как монетизировать свою '
#                                  'идею? Рассказывает [id13716595|Иван '
#                                  'Расторгуев], руководитель направления '
#                                  'развития и монетизации [club166562603|VK '
#                                  'Mini Apps]. Читайте в статье для vc.ru ✨',
#                          'views': {'count': 425559}},
#                         {'attachments': [{'photo': {'access_key': 'f0165c4a228214c6c5',
#                                                     'album_id': -7,
#                                                     'date': 1663058504,
#                                                     'id': 457333443,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1320329,
#                                                     'sizes': [{'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun4-17.userapi.com/impg/-4DWzKipIBbEAZbZ2HyiSoVioYndjFLxi_5QMg/4CCWDZCIdfY.jpg?size=75x75&quality=95&sign=74c9761804b851d7463b0df81156c98e&c_uniq_tag=U2umoDs-5a3VPkV2Lt3OJTah1Oxs6KDThDaY4-8-twI&type=album',
#                                                                'width': 75},
#                                                               {'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun4-17.userapi.com/impg/-4DWzKipIBbEAZbZ2HyiSoVioYndjFLxi_5QMg/4CCWDZCIdfY.jpg?size=130x130&quality=95&sign=0c3eed9bde18f686f7744d94642e6b09&c_uniq_tag=0vL9qqIe1srzCQaCj890AJHY9cPUGv3O8wMeOJs7m9M&type=album',
#                                                                'width': 130},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'width': 510}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 110,
#                                       'groups_can_post': True},
#                          'date': 1663059091,
#                          'from_id': -22822305,
#                          'hash': 'vzegC3VDc_RosXcRMA',
#                          'id': 1320329,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 1487,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 833, 'user_reposted': 0},
#                          'text': 'Работаете в большой компании с десятками '
#                                  'офисов в разных городах? Или у вас стартап с '
#                                  'друзьями и энтузиастами, разбросанными по '
#                                  'всему миру? Может, вы проводите онлайн-уроки '
#                                  'или целые конференции? В любом случае одна '
#                                  'из составляющих успеха — налаженная связь '
#                                  'без ограничений по времени и количеству '
#                                  'участников. Чтобы она была доступна каждому, '
#                                  'мы создали приложение VK Звонков для '
#                                  'переговорных и конференц-залов. Скачать его '
#                                  'можно здесь: calls.vk.com. \n'
#                                  ' \n'
#                                  'Приложение адаптировано для '
#                                  'профессионального оборудования: например, '
#                                  'управлять звонком можно будет с помощью '
#                                  'контроллера, если он поддерживает технологию '
#                                  'мультитач. Доступны демонстрация экрана в '
#                                  '4К, планирование встреч и все остальные '
#                                  'возможности VK Звонков — бесплатно. Для '
#                                  'использования достаточно компьютера или '
#                                  'планшета на базе Windows 7 или новее и VK '
#                                  'ID. К устройству также можно подключить '
#                                  'дополнительное оборудование: телевизор или '
#                                  'проектор, колонки, камеры и микрофоны. \n'
#                                  ' \n'
#                                  'Системных администраторов и энтузиастов мы '
#                                  'приглашаем протестировать приложение для '
#                                  'конференц-залов на своих устройствах и '
#                                  'поделиться опытом. Для участия заполните '
#                                  'форму по '
#                                  '[https://vk.com/app6013442_-215867231?form_id=2#form_id=2|ссылке].',
#                          'views': {'count': 626489}},
#                         {'attachments': [{'link': {'caption': 'vc.ru',
#                                                    'description': 'Истории '
#                                                                   'участников '
#                                                                   'VK Testers '
#                                                                   '(а теперь '
#                                                                   'успешных '
#                                                                   'тестировщиков) '
#                                                                   '— о '
#                                                                   'программе, '
#                                                                   'конкуренции '
#                                                                   'и '
#                                                                   'эксклюзивном '
#                                                                   'доступе к '
#                                                                   'новым '
#                                                                   'продуктам.',
#                                                    'photo': {'album_id': -26,
#                                                              'date': 1662718584,
#                                                              'id': 457416388,
#                                                              'owner_id': 2000011174,
#                                                              'sizes': [{'height': 480,
#                                                                         'type': 'k',
#                                                                         'url': 'https://sun4-10.userapi.com/impg/yOUWzrxZIrClLgBTpkSUimoY3PEVAE9BkqdgCw/l-PyTNn9Qo8.jpg?size=1074x480&quality=96&sign=8745c16146023a9baa97765049d8dea5&c_uniq_tag=GKvMDNH7e0FFgLU1NPbMotP-5CqjJ6RjvYzvWXMzas4&type=share',
#                                                                         'width': 1074},
#                                                                        {'height': 240,
#                                                                         'type': 'l',
#                                                                         'url': 'https://sun4-10.userapi.com/impg/yOUWzrxZIrClLgBTpkSUimoY3PEVAE9BkqdgCw/l-PyTNn9Qo8.jpg?size=537x240&quality=96&sign=c628fb2e4219dd14994a2ef49b12ab35&c_uniq_tag=CCngOSejEFRgWCehQVFNz3P-0AJYxfANpzadyTqqQ30&type=share',
#                                                                         'width': 537},
#                                                                        {'height': 80,
#                                                                         'type': 'm',
#                                                                         'url': 'https://sun4-10.userapi.com/impg/yOUWzrxZIrClLgBTpkSUimoY3PEVAE9BkqdgCw/l-PyTNn9Qo8.jpg?size=130x80&quality=96&crop=147,0,780,480&sign=3d56e38d8526d826624386492453267e&c_uniq_tag=4ovzZp6tMxBuD_8SxSalhZD5obWASju_ziBIgj97w5o&type=share',
#                                                                         'width': 130},
#                                                                        {'height': 140,
#                                                                         'type': 'p',
#                                                                         'url': 'https://sun4-10.userapi.com/impg/yOUWzrxZIrClLgBTpkSUimoY3PEVAE9BkqdgCw/l-PyTNn9Qo8.jpg?size=260x140&quality=96&crop=91,0,891,480&sign=cec34fa14df75512cb1323bd3c79a30f&c_uniq_tag=8VawvGX08SxTCfbe-ef0UJxHpKNzQuxO_kwaOmDlULo&type=share',
#                                                                         'width': 260},
#                                                                        {'height': 35,
#                                                                         'type': 's',
#                                                                         'url': 'https://sun4-10.userapi.com/impg/yOUWzrxZIrClLgBTpkSUimoY3PEVAE9BkqdgCw/l-PyTNn9Qo8.jpg?size=75x35&quality=96&crop=22,0,1029,480&sign=d809c1bd0dac70c6bc382cfa795e8773&c_uniq_tag=Gql4VOVD-gGYVext-r4sA-8shGrL2we3FZ5LvYe9LHc&type=share',
#                                                                         'width': 75},
#                                                                        {'height': 80,
#                                                                         'type': 'x',
#                                                                         'url': 'https://sun4-10.userapi.com/impg/yOUWzrxZIrClLgBTpkSUimoY3PEVAE9BkqdgCw/l-PyTNn9Qo8.jpg?size=150x80&quality=96&crop=87,0,900,480&sign=dc3728b5c3c77ff34b36ec9389090ce5&c_uniq_tag=GzleQ0ni7IlHHAe5OlJH7dh-7Voe744lj-RI_L95MAA&type=share',
#                                                                         'width': 150}],
#                                                              'text': '',
#                                                              'user_id': 100},
#                                                    'title': 'Кто на самом деле '
#                                                             'охотится за '
#                                                             'багами '
#                                                             '«ВКонтакте»?',
#                                                    'url': 'https://vc.ru/vk/498087-kto-na-samom-dele-ohotitsya-za-bagami-vkontakte'},
#                                           'type': 'link'}],
#                          'comments': {'can_post': 1,
#                                       'count': 315,
#                                       'groups_can_post': True},
#                          'date': 1662719180,
#                          'from_id': -22822305,
#                          'hash': '2LI6SehLBBiaC5V_tA',
# ...
#                                                                'width': 510},
#                                                               {'height': 60,
#                                                                'type': 's',
#                                                                'url': 'https://sun4-11.userapi.com/impg/bhyVeKT81ybTL0RziUcQRLXhpPNAkddKpV-4jg/NiW_lu5g8mM.jpg?size=75x60&quality=96&sign=74d3d4e22b02c071042d679f277abeb9&c_uniq_tag=0gn6XN3IsBV8Ejr8SouEv9YCGuBhtcHfbQ6njV1-j44&type=album',
#                                                                'width': 75},
#                                                               {'height': 1200,
#                                                                'type': 'w',
#                                                                'url': 'https://sun4-11.userapi.com/impg/bhyVeKT81ybTL0RziUcQRLXhpPNAkddKpV-4jg/NiW_lu5g8mM.jpg?size=1500x1200&quality=96&sign=e0f6209475ed94d5d80bc7f6a7d035d8&c_uniq_tag=Bc_ZGkcBuYFd8ZSMaZgA7Og7032L2oi3DF8rAR0eZOc&type=album',
#                                                                'width': 1500},
#                                                               {'height': 483,
#                                                                'type': 'x',
#                                                                'url': 'https://sun4-11.userapi.com/impg/bhyVeKT81ybTL0RziUcQRLXhpPNAkddKpV-4jg/NiW_lu5g8mM.jpg?size=604x483&quality=96&sign=78494e127cab146c096489321c91c840&c_uniq_tag=D9eNGspvi6mGy8pqNx8zJntSOOsylsQZIyjmgmG9TDU&type=album',
#                                                                'width': 604},
#                                                               {'height': 646,
#                                                                'type': 'y',
#                                                                'url': 'https://sun4-11.userapi.com/impg/bhyVeKT81ybTL0RziUcQRLXhpPNAkddKpV-4jg/NiW_lu5g8mM.jpg?size=807x646&quality=96&sign=963a6ab777ce29bcf141744a233a9dbb&c_uniq_tag=F0mtmTm3Wdw4wVzJj7pS8gZLzQV7msHbGrgpsr-6bVg&type=album',
#                                                                'width': 807},
#                                                               {'height': 1024,
#                                                                'type': 'z',
#                                                                'url': 'https://sun4-11.userapi.com/impg/bhyVeKT81ybTL0RziUcQRLXhpPNAkddKpV-4jg/NiW_lu5g8mM.jpg?size=1280x1024&quality=96&sign=9d9a3ce8a799cf883273be78cda70143&c_uniq_tag=pSHxhG5Uv6TOCOIWVX5QjtxJqKIaO6mHUgbV3NqY94A&type=album',
#                                                                'width': 1280}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 796,
#                                       'groups_can_post': True},
#                          'date': 1608105691,
#                          'edited': 1610985451,
#                          'from_id': -22822305,
#                          'hash': 'PbURp6aJ1AyDeVxUnA',
#                          'id': 1144173,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 3034,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 527, 'user_reposted': 0},
#                          'text': 'Сообщества были и остаются одной из главных '
#                                  'составляющих ВКонтакте. Мы хотим, чтобы '
#                                  'авторы качественных и интересных проектов '
#                                  'могли зарабатывать на своём деле. Встречайте '
#                                  'партнёрскую программу — она заменит '
#                                  'существующую рекламную сеть и станет основой '
#                                  'единой платформы монетизации для создателей '
#                                  'контента. Больше подробностей о ней мы '
#                                  'расскажем в начале следующего года.\n'
#                                  '\n'
#                                  'В новой программе система стала более '
#                                  'гибкой, и у тех, кто учтёт новые факторы в '
#                                  'своих публикациях, выплаты могут вырасти на '
#                                  '50%. Охваты больше не единственный критерий '
#                                  'оценки. Теперь на заработок будут влиять '
#                                  'сразу несколько дополнительных критериев.\n'
#                                  '\n'
#                                  'Администраторы смогут увеличить свой доход, '
#                                  'если будут привлекать аудиторию с внешних '
#                                  'ресурсов. Контент должен быть интересен и '
#                                  'пользователям ВКонтакте — как подписчикам '
#                                  'сообщества, так и тем, кто увидит записи в '
#                                  'рекомендациях или у друзей. Также заработок '
#                                  'будет выше, если автор выбирает нативные '
#                                  'форматы: например, загружает видео в плеер '
#                                  'ВКонтакте, а вместо ссылки на сторонний сайт '
#                                  'оформляет текст в редакторе статей. Есть и '
#                                  'факторы, которые негативно влияют на '
#                                  'результаты расчётов: доход будет снижен за '
#                                  'плагиат в сообществе или нарушение правил '
#                                  'ВКонтакте. Мы также усилили защиту от '
#                                  'накрутки количества подписчиков и охватов — '
#                                  'теперь у нарушителей меньше шансов получить '
#                                  'незаслуженные деньги.\n'
#                                  '\n'
#                                  'Обновились правила: '
#                                  'vk.com/page-59800369_53538391 — контенту '
#                                  'уделено больше внимания. Если вы участник '
#                                  'рекламной сети, к партнёрской программе вы '
#                                  'подключитесь автоматически 1 февраля 2021 '
#                                  'года. У вас будет время, чтобы привести в '
#                                  'соответствие с требованиями свои сообщества. '
#                                  'Они будут регулярно проверяться. Нам важно, '
#                                  'чтобы вы продолжали держать планку качества, '
#                                  'радуя своих подписчиков. \n'
#                                  '\n'
#                                  'Новые сообщества могут подать заявку уже '
#                                  'сейчас — достаточно нажать кнопку '
#                                  '«Подключиться» в разделе «Монетизация». Для '
#                                  'них расширенные правила начинают действовать '
#                                  'сегодня. \n'
#                                  '\n'
#                                  'Узнайте больше о новой программе в '
#                                  '[https://vk.com/@adminsclub-partnerskaya-programma-vkontakte|статье].',
#                          'views': {'count': 1293540}},
#                         {'attachments': [{'photo': {'access_key': '8955623cfa0e25534c',
#                                                     'album_id': -7,
#                                                     'date': 1608033464,
#                                                     'id': 457314448,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1140804,
#                                                     'sizes': [{'height': 100,
#                                                                'type': 'm',
#                                                                'url': 'https://sun4-11.userapi.com/impg/fk_4bvWLnCDfmtKHPedHLKY_xRW638IxCBXNIQ/vAkd86TVEfM.jpg?size=130x100&quality=96&sign=1377034afb55696ede2c281462a1d683&c_uniq_tag=Oe9cFwzRKgM174IeNZKLNSjV6IwHEjeWqh_pvVFywBg&type=album',
#                                                                'width': 130},
#                                                               {'height': 100,
#                                                                'type': 'o',
#                                                                'url': 'https://sun4-11.userapi.com/impg/fk_4bvWLnCDfmtKHPedHLKY_xRW638IxCBXNIQ/vAkd86TVEfM.jpg?size=130x100&quality=96&sign=1377034afb55696ede2c281462a1d683&c_uniq_tag=Oe9cFwzRKgM174IeNZKLNSjV6IwHEjeWqh_pvVFywBg&type=album',
#                                                                'width': 130},
#                                                               {'height': 153,
#                                                                'type': 'p',
#                                                                'url': 'https://sun4-11.userapi.com/impg/fk_4bvWLnCDfmtKHPedHLKY_xRW638IxCBXNIQ/vAkd86TVEfM.jpg?size=200x153&quality=96&sign=b5a1220567228fde00c35ab75d293c0a&c_uniq_tag=AfjWtbQgsjC7D-yDVeCVuF_ul3rcuKeqjoIm7xfaj60&type=album',
#                                                                'width': 200},
#                                                               {'height': 245,
#                                                                'type': 'q',
#                                                                'url': 'https://sun4-11.userapi.com/impg/fk_4bvWLnCDfmtKHPedHLKY_xRW638IxCBXNIQ/vAkd86TVEfM.jpg?size=320x245&quality=96&sign=4a177121e78f1890b137f30a46db6e5f&c_uniq_tag=0VEBtp9z587O9tLVsj-rv4WihoD1kJfOvoQd97DK2GA&type=album',
#                                                                'width': 320},
#                                                               {'height': 391,
#                                                                'type': 'r',
#                                                                'url': 'https://sun4-11.userapi.com/impg/fk_4bvWLnCDfmtKHPedHLKY_xRW638IxCBXNIQ/vAkd86TVEfM.jpg?size=510x391&quality=96&sign=dfad39aff93623d76bd3c6a702ac23ba&c_uniq_tag=TbxRwxp9oTEDkVJcDUCxYB5kScY-cyk680GGSAAhvm8&type=album',
#                                                                'width': 510},
#                                                               {'height': 57,
#                                                                'type': 's',
#                                                                'url': 'https://sun4-11.userapi.com/impg/fk_4bvWLnCDfmtKHPedHLKY_xRW638IxCBXNIQ/vAkd86TVEfM.jpg?size=75x57&quality=96&sign=b5b7f6e4c9c991526984fbbb2d6a5c1c&c_uniq_tag=fhwHUgtDzHRbYX3Qhi33UnPFuMpuuNhbul8-eOX2m2k&type=album',
#                                                                'width': 75},
#                                                               {'height': 1963,
#                                                                'type': 'w',
#                                                                'url': 'https://sun4-11.userapi.com/impg/fk_4bvWLnCDfmtKHPedHLKY_xRW638IxCBXNIQ/vAkd86TVEfM.jpg?size=2560x1963&quality=96&sign=b028fe3f6d81badb1d513113d1187ece&c_uniq_tag=yNcVIic0hBqrG9bFSmP_5aPBih-slQpOzg9W9KJa2bw&type=album',
#                                                                'width': 2560},
#                                                               {'height': 463,
#                                                                'type': 'x',
#                                                                'url': 'https://sun4-11.userapi.com/impg/fk_4bvWLnCDfmtKHPedHLKY_xRW638IxCBXNIQ/vAkd86TVEfM.jpg?size=604x463&quality=96&sign=6fb58ca40402363c1a3ccb0a4c05b52b&c_uniq_tag=Q8YdjtuoGuX8rJ41m0rCpQvMuqapSAqGGOdCwF3BtmI&type=album',
#                                                                'width': 604},
#                                                               {'height': 619,
#                                                                'type': 'y',
#                                                                'url': 'https://sun4-11.userapi.com/impg/fk_4bvWLnCDfmtKHPedHLKY_xRW638IxCBXNIQ/vAkd86TVEfM.jpg?size=807x619&quality=96&sign=9a2735a6f4ae9155822c3eb0ba74744f&c_uniq_tag=EXJimaAgQbw-yxBqQZHkkOxZDvKxkvCqgNjlAgynCaw&type=album',
#                                                                'width': 807},
#                                                               {'height': 981,
#                                                                'type': 'z',
#                                                                'url': 'https://sun4-11.userapi.com/impg/fk_4bvWLnCDfmtKHPedHLKY_xRW638IxCBXNIQ/vAkd86TVEfM.jpg?size=1280x981&quality=96&sign=972aa25ad0f77da38a3cfe3145eae104&c_uniq_tag=rvnD6-xRneQLb8Ti25XySgnDQ5rU9DrpvMwLzzNE0FE&type=album',
#                                                                'width': 1280}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 3258,
#                                       'groups_can_post': True},
#                          'date': 1608033618,
#                          'from_id': -22822305,
#                          'hash': '7j1W9Jcs_KYo92g1nQ',
#                          'id': 1140804,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 6833,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 2630, 'user_reposted': 0},
#                          'text': 'В наступающий год — со свежим дизайном!\n'
#                                  '\n'
#                                  'Во время тестирования нового фирменного '
#                                  'стиля ВКонтакте мы получили много обращений '
#                                  'с просьбами включить его для всех '
#                                  'пользователей. Сделано! Внешний вид сайта '
#                                  'изменится уже сегодня. Актуальный логотип, '
#                                  'собственный шрифт и лёгкая цветовая гамма '
#                                  'сделают все версии VK визуально едиными и '
#                                  'узнаваемыми.\n'
#                                  '\n'
#                                  'В октябре новую версию ВКонтакте для '
#                                  'компьютера оценили 100 тысяч добровольцев, '
#                                  'из них 78% продолжили использовать свежий '
#                                  'дизайн. Пробный запуск помог нам понять, что '
#                                  'переход будет плавным: статистика '
#                                  'показывает, что тестовой группе не пришлось '
#                                  'менять свои привычки.\n'
#                                  '\n'
#                                  'Читайте про обновление дизайна в нашем '
#                                  '[vk.com/blog/design-2020|блоге].',
#                          'views': {'count': 1593541}}]}}

# %%
stats = {} 
count_post = 0 # Счётчик «непустых» сообщений
for record in response.json()['response']['items'][:]:
    title = record['text'][:30] 
    if title: 
        stats[title] = [record['comments']['count'], record['likes']['count'], record['reposts']['count'], record['date']] 
        count_post += 1 
    if count_post < 10: 
        continue 
    else: 
        break 
pprint(stats)
# Out:
# {'8 сентября мы представим сразу': [198, 1511, 744, 1662392333],
#  'Content Day — уже сегодня!\n\nБо': [194, 1259, 735, 1662627917],
#  'Все интересные обновления ВКон': [130, 323, 62, 1664904760],
#  'Выучить английский, выбрать по': [255, 1412, 863, 1663082160],
#  'Друзья!\n\nСейчас некоторые прил': [2168, 4386, 5000, 1664267982],
#  'Как ВКонтакте изменилась за ав': [369, 1425, 621, 1662134735],
#  'Почему VK Звонки?\nПотому что д': [1195, 1637, 725, 1663240511],
#  'Работаете в большой компании с': [110, 1487, 833, 1663059091],
#  'Сегодня мы провели Content Day': [265, 1495, 875, 1662655466],
#  'Сегодня отмечается День тестир': [315, 1719, 939, 1662719180]}

# %%
list_example = [1,2,3,4,5]
another_list = list_example
another_list[0] = 100
print(list_example)
# Out:
# [100, 2, 3, 4, 5]

# %%
a = 5
b = 5
result = (b, a)[a > b]
print(result)
# Out:
# 5

# %%
def sum_lst(lst):
    # Выводим текущее значение lst
    print(lst)
    # Задаём условие выхода из рекурсии
    if len(lst) == 0:return 0
    # Во всех других случаях возвращаем
    # сумму первого элемента списка 
    # и результат суммирования оставшихся
    return lst[0] + sum_lst(lst[1:])
 
my_lst = [10, 21, 24, 12]
print(sum_lst(my_lst))
# Out:
# [10, 21, 24, 12]
# [21, 24, 12]
# [24, 12]
# [12]
# []
# 67

# %%
def fibo(n):
    n1 = 1
    n2 = 2
    count 
    if count == n

# %%
one = [1, "2", 3, "4"]
two = ("a", "b", "c", "d")

one.append(5)

# %%
my_dict = {1 : "1", 2 : "2"}

for key, value in my_dict.items():
    print(key, value)
# Out:
# 1 1
# 2 2
